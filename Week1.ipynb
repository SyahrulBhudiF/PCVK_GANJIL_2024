# %% [markdown]
# <a href="https://colab.research.google.com/github/SyahrulBhudiF/PCVK_GANJIL_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MODUL 1 – Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra**
#
#
#
# ---
# Nama  : Syahrul Bhudi Ferdiansyah<br>
# Kelas : TI - 3B<br>
# Absen : 26<br>
#
# ---
#
#
#
# Citra Digital (Citra Raster) adalah representasi numerik dari citra dua dimensi. Nilai numerik yang direpresentasikan umumnya adalah nilai biner 8 bit. Nilai biner ini disimpan pada elemen citra yang sering disebut sebagai pixel. Citra digital berisi pixel yang jumlah baris dan kolomnya tetap. Pixel adalah elemen gambar terkecil dari citra digital. Pixel disimpan pada memory computer sebagai map raster, yaitu array dua dimensi bertipe integer
#
# Pada Langkah pertama: Kita perlu mempersiapkan beberapa library yang akan digunakan seperti:
#
# * Numpy: Library untuk komputasi numerik dengan array multidimensi dan operasi matematis yang efisien.
# * Pandas: Library untuk manipulasi dan analisis data tabular menggunakan struktur data seperti DataFrame dan Series.
# * Cv2 (OpenCV): Library untuk pemrosesan citra dan visi komputer, termasuk fungsi untuk manipulasi gambar dan video.
# * Skimage (Scikit-image): Library untuk pemrosesan citra digital, menyediakan algoritma dan fungsi untuk analisis dan transformasi gambar.
# * Matplotlib: Library untuk visualisasi data, memungkinkan pembuatan berbagai jenis grafik dan plot untuk representasi data.
# * PIL (Python Imaging Library): Library untuk membuka, memanipulasi, dan menyimpan berbagai format gambar. PIL adalah pustaka lama yang telah digantikan oleh Pillow, yang merupakan fork dan peningkatan dari PIL.

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
from matplotlib.pylab import plt

# %% [markdown]
# Pada langkah kedua: Kita akan membaca file gambar, menampilkan serta memodifikasi

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://static0.gamerantimages.com/wordpress/wp-content/uploads/2023/06/genshin-impact-raiden-shogun-burst.jpg?q=50&fit=crop&w=943&h=530&dpr=1.5"
    ]

for url in urls:
  image = io.imread(url)                            #Read Image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #Rezize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #Convert image to RGB
  final_frame = cv.hconcat((image,image_2))         #Concatenate image
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=944x265>

# %% [markdown]
# Pada langkah ketiga: Kita melihat ukuran dari suatu gambar dengan cara sbb:

# %%
# Mendapatkan dimensi gambar
tinggi = image_2.shape[0]
lebar = image_2.shape[1]

# Mencetak resolusi gambar
print("Resolusi image: tinggi x lebar = ", tinggi, ' x ', lebar)

# Menampilkan gambar hasil
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  265  x  472
# <PIL.Image.Image image mode=RGB size=472x265>

# %% [markdown]
# Pada langkah keempat: Kita mengakses pixel dan memodifikasi warna dari suatu pixel.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=944x265>

# %% [markdown]
# #***PERTANYAAN***
#
# ###1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# Jawaban :
# Dijalankan menggunakan Google Colab di karenakan mempermudah untuk file sharing dan dapat menggunakan libary python tanpa menginstal
#
# ###2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# Jawaban :
# Terdapat beberapa library yang tidak digunakan untuk pratikum ini diantaranya library pandas (digunakan untuk mengelolah data dengan format csv, Excel, dan sql) dan mathplotlib (digunakan untuk visualisasi data)
#
# ###3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : ![image.png](data:image/png;base64,...)Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# Jawaban :
# Kode program di atas digunakan untuk mengubah ukuran gambar agar semua gambar yang di inputkan memiliki ukuran yang sama, apabila tidak dilakukan ukuran gabar satu dengan yang lain akan berbeda
#
# ###4. Perhatikan potongan kode progam berikut :  ![image.png](data:image/png;base64,...)
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawaban :
# mengatur atau merubah format warna menjadi putih pada setiap pixel yang telah di tentukan pada perulangan
#
# ##5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawaban : Keterkaitn antara pixel dengan resolusi gambar yaitu bahwwa resolusi gambar menunjukan jumlah pixel yang digunakan untuk menampilkan gambar, jadi jika resolusi gambar tinggi maka jumlah kepadatan pixel juga tinggi begitupula sebaliknya

# %% [markdown]
# # ***Tugas***
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
# Image Garis Vertikal
image_4 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_4[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat([image_2, image_4])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=944x265>

# %%
image_5 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)

# Membuat garis menyilang dari kiri atas ke kanan bawah
for x in range(min(tinggi, lebar)):
    image_5[x, int((lebar/tinggi) * x)] = [0, 0, 0]

# Membuat garis menyilang dari kanan atas ke kiri bawah
for x in range(min(tinggi, lebar)):
    image_5[x, lebar - int((lebar/tinggi) * x) - 1] = [0, 0, 0]

# Menggabungkan gambar asli dengan gambar yang sudah diberi garis X
final_frame = cv.hconcat([image_2, image_5])

# Menampilkan gambar akhir menggunakan cv2_imshow
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=944x265>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu

# %%
y_posisi = 150

# Panjang garis horizontal yang diinginkan
panjang_garis = 200

# Menentukan posisi awal dan akhir garis horizontal
awal_garis = (image.shape[1] - panjang_garis) // 2
akhir_garis = awal_garis + panjang_garis

# Menggambar garis horizontal berwarna putih di bawah dagu karakter
for x in range(awal_garis, akhir_garis):
    image[y_posisi, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=944x265>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_6 = cv.cvtColor(image_2, cv.COLOR_BGR2RGB)

#mengatur posisi plot
uk_plot = 90 #ukuran plot (persegi)
awal_garis_x = 200  #awal titik x
awal_garis_y = 40  #akhir titik y

#mengatur pixel akhir
akhir_garis_x = awal_garis_x + uk_plot
akhir_garis_y = awal_garis_y + uk_plot

#plot
for x in range(awal_garis_x, akhir_garis_x):
  for y in range(awal_garis_y, akhir_garis_y):
    image_6[y, x] = [0, 0, 0]

final_frame = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=944x265>
